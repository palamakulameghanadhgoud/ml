# %%
import pandas as pd
df= pd.read_excel('D:/ml projects\Sample - EU Superstore.xls')
print(df.head())
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\megha\AppData\Local\Temp\ipykernel_12616\3487150335.py:2: SyntaxWarning: invalid escape sequence '\S'
#   df= pd.read_excel('D:/ml projects\Sample - EU Superstore.xls')
#    Row ID         Order ID Order Date Dispatch Date   Delivery Mode  \
# 0       1  ES-2024-1311038 2024-02-07    2024-02-11  Standard Class
# 1       2  ES-2024-1311038 2024-02-07    2024-02-11  Standard Class
# 2       3  ES-2024-1311038 2024-02-07    2024-02-11  Standard Class
# 3       4  ES-2024-1311038 2024-02-07    2024-02-11  Standard Class
# 4       5  ES-2024-1311038 2024-02-07    2024-02-11  Standard Class
#
#   Customer ID   Customer Name    Segment   City State/Province  \
# 0    AS-10045  Aaron Smayling  Corporate  Leeds        England
# 1    AS-10045  Aaron Smayling  Corporate  Leeds        England
# 2    AS-10045  Aaron Smayling  Corporate  Leeds        England
# ...

# %%
print(df.shape)
# Out:
# (10000, 20)

# %%
print(df.tail())
# Out:
#       Row ID         Order ID Order Date Dispatch Date   Delivery Mode  \
# 9995    9996  ES-2021-3780358 2021-11-16    2021-11-19     First Class
# 9996    9997  ES-2022-5371207 2022-01-25    2022-01-29  Standard Class
# 9997    9998  ES-2022-5371207 2022-01-25    2022-01-29  Standard Class
# 9998    9999  ES-2022-5371207 2022-01-25    2022-01-29  Standard Class
# 9999   10000  ES-2022-5371207 2022-01-25    2022-01-29  Standard Class
#
#      Customer ID      Customer Name      Segment     City State/Province  \
# 9995    CC-12100    Chad Cunningham  Home Office   Rovigo         Veneto
# 9996    GB-14575  Giulietta Baptist     Consumer  Hamburg        Hamburg
# 9997    GB-14575  Giulietta Baptist     Consumer  Hamburg        Hamburg
# 9998    GB-14575  Giulietta Baptist     Consumer  Hamburg        Hamburg
# 9999    GB-14575  Giulietta Baptist     Consumer  Hamburg        Hamburg
#
#      Country/Region   Region       Product ID         Category Sub-Category  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Dispatch Date', 'Delivery Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State/Province',
#        'Country/Region', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
print(df.describe(include='all'))
# Out:
#              Row ID         Order ID                  Order Date  \
# count   10000.00000            10000                       10000
# unique          NaN             4596                         NaN
# top             NaN  ES-2022-5776825                         NaN
# freq            NaN               12                         NaN
# mean     5000.50000              NaN  2023-05-15 02:59:51.360000
# min         1.00000              NaN         2021-01-01 00:00:00
# 25%      2500.75000              NaN         2022-06-30 00:00:00
# 50%      5000.50000              NaN         2023-07-09 00:00:00
# 75%      7500.25000              NaN         2024-06-03 00:00:00
# max     10000.00000              NaN         2024-12-31 00:00:00
# std      2886.89568              NaN                         NaN
#
#                         Dispatch Date   Delivery Mode Customer ID  \
# count                           10000           10000       10000
# ...

# %%
print(df.groupby('Category')[['Sales', 'Profit']].sum())
# Out:
#                         Sales       Profit
# Category
# Furniture        7.791030e+05   68850.1395
# Office Supplies  1.046307e+06  159706.9440
# Technology       1.112679e+06  144272.6580

# %%
df['Sales'].unique()
# Out:
# array([ 79.2 , 388.92,  35.19, ...,  10.86, 870.9 , 502.95])

# %%
df.to_csv('cleaned',index=False)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10000 non-null  int64
#  1   Order ID        10000 non-null  object
#  2   Order Date      10000 non-null  datetime64[ns]
#  3   Dispatch Date   10000 non-null  datetime64[ns]
#  4   Delivery Mode   10000 non-null  object
#  5   Customer ID     10000 non-null  object
#  6   Customer Name   10000 non-null  object
#  7   Segment         10000 non-null  object
#  8   City            10000 non-null  object
#  9   State/Province  10000 non-null  object
#  10  Country/Region  10000 non-null  object
#  11  Region          10000 non-null  object
#  12  Product ID      10000 non-null  object
#  13  Category        10000 non-null  object
#  14  Sub-Category    10000 non-null  object
#  15  Product Name    10000 non-null  object
# ...

# %%
df['Sales']
# Out:
# 0        79.20
# 1       388.92
# 2        35.19
# 3        50.94
# 4       307.44
#          ...
# 9995     59.82
# 9996      6.66
# 9997     96.66
# 9998    502.95
# 9999    152.28
# Name: Sales, Length: 10000, dtype: float64

# %%
df['Sales','City']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\megha\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Sales', 'City')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ...

# %%
df.loc[0]
# Out:
# Row ID                                 1
# Order ID                 ES-2024-1311038
# Order Date           2024-02-07 00:00:00
# Dispatch Date        2024-02-11 00:00:00
# Delivery Mode             Standard Class
# Customer ID                     AS-10045
# Customer Name             Aaron Smayling
# Segment                        Corporate
# City                               Leeds
# State/Province                   England
# Country/Region            United Kingdom
# Region                             North
# Product ID               OFF-ST-10000988
# Category                 Office Supplies
# Sub-Category                     Storage
# Product Name      Fellowes Folders, Blue
# Sales                               79.2
# Quantity                               3
# Discount                             0.0
# Profit                              39.6
# Name: 0, dtype: object

# %%
df[df['Profit']>1000]
# Out:
#       Row ID         Order ID Order Date Dispatch Date   Delivery Mode  \
# 8          9  ES-2022-5113958 2022-08-02    2022-08-07    Second Class
# 206      207  ES-2023-4165099 2023-02-19    2023-02-26  Standard Class
# 375      376  ES-2021-1712442 2021-08-17    2021-08-22  Standard Class
# 709      710  ES-2024-3977309 2024-11-12    2024-11-16  Standard Class
# 941     7725  IT-2024-2529211 2024-07-09    2024-07-10     First Class
# 1316    1317  ES-2021-4500805 2021-11-06    2021-11-10    Second Class
# 1350    1351  ES-2021-4699764 2021-03-15    2021-03-18    Second Class
# 1756    1757  ES-2021-2257437 2021-08-11    2021-08-18  Standard Class
# 1774    1775  ES-2024-1651774 2024-09-08    2024-09-14  Standard Class
# 1826    1827  ES-2023-4779701 2023-07-08    2023-07-11     First Class
# 1875    1204  ES-2022-1881846 2022-12-26    2022-12-30  Standard Class
# 1935    1936  IT-2021-3911927 2021-12-27    2022-01-01  Standard Class
# ...

# %%
df.fillna(2, inplace=True)
